# %%
import pandas as pd

# %%
titles = pd.read_csv("../Resources/titles.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29284\109150671.py in <module>
# ----> 1 titles = pd.read_csv("../Resources/titles.csv")
#
# c:\Users\equan\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
credits = pd.read_csv("../Resources/credits.csv")

# %%
titles_df = pd.DataFrame(titles)

# %%
titles_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# ...

# %%
credits_df = pd.DataFrame(credits)
credits_df.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
credits_df.dtypes
# Out:
# person_id     int64
# id           object
# name         object
# character    object
# role         object
# dtype: object

# %%
titles_df.dtypes
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %%
titles_df.notnull().sum()
# Out:
# id                      5806
# title                   5805
# type                    5806
# description             5788
# release_year            5806
# age_certification       3196
# runtime                 5806
# genres                  5806
# production_countries    5806
# seasons                 2047
# imdb_id                 5362
# imdb_score              5283
# imdb_votes              5267
# tmdb_popularity         5712
# tmdb_score              5488
# dtype: int64

# %%
titles_df.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# tmdb_popularity           94
# tmdb_score               318
# dtype: int64

# %%
titles_df.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm14873                          Dirty Harry  MOVIE
# 7  tm185072                         My Fair Lady  MOVIE
# 8   tm98978                      The Blue Lagoon  MOVIE
# 9  tm119281                     Bonnie and Clyde  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# ...

# %%
credits_df.isnull().sum()
# Out:
# person_id       0
# id              0
# name            0
# character    9627
# role            0
# dtype: int64

# %%
credits_df = credits_df.drop(columns=['character'])
credits_df
# Out:
#        person_id         id                    name      role
# 0           3748    tm84618          Robert De Niro     ACTOR
# 1          14658    tm84618            Jodie Foster     ACTOR
# 2           7064    tm84618           Albert Brooks     ACTOR
# 3           3739    tm84618           Harvey Keitel     ACTOR
# 4          48933    tm84618         Cybill Shepherd     ACTOR
# ...          ...        ...                     ...       ...
# 77208    1347054  tm1098060  Nnenna Rachael Okonkwo     ACTOR
# 77209     157590  tm1098060           Lucien Morgan     ACTOR
# 77210     129059  tm1098060        Magdalena Korpas     ACTOR
# 77211    2050199  tm1098060        Mistura Olusanya     ACTOR
# 77212    2050423  tm1098060              Yemi Amodu  DIRECTOR
#
# [77213 rows x 4 columns]

# %%
credits_df.isnull().sum()
# Out:
# person_id    0
# id           0
# name         0
# role         0
# dtype: int64

# %%
titles2_df = titles_df.drop(columns=["description", "seasons"])
titles2_df
# Out:
#              id                                title   type  release_year  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1       tm84618                          Taxi Driver  MOVIE          1976
# 2      tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3       tm70993                        Life of Brian  MOVIE          1979
# 4      tm190788                         The Exorcist  MOVIE          1973
# ...         ...                                  ...    ...           ...
# 5801  tm1014599                            Fine Wine  MOVIE          2021
# 5802  tm1108171                       Edis Starlight  MOVIE          2021
# 5803  tm1045018                                Clash  MOVIE          2021
# 5804  tm1098060                       Shadow Parties  MOVIE          2021
# 5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW          2021
#
#      age_certification  runtime                             genres  \
# ...

# %%
titles3_df = titles2_df.rename({'type':'movie'}, axis="columns")

# %%
list(titles3_df)
# Out:
# ['id',
#  'title',
#  'movie',
#  'release_year',
#  'age_certification',
#  'runtime',
#  'genres',
#  'production_countries',
#  'imdb_id',
#  'imdb_score',
#  'imdb_votes',
#  'tmdb_popularity',
#  'tmdb_score']

# %%
titles4_df = titles3_df[titles3_df['movie'].str.contains('MOVIE')]

# %%
titles4_df
# Out:
#              id                            title  movie  release_year  \
# 1       tm84618                      Taxi Driver  MOVIE          1976
# 2      tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3       tm70993                    Life of Brian  MOVIE          1979
# 4      tm190788                     The Exorcist  MOVIE          1973
# 6       tm14873                      Dirty Harry  MOVIE          1971
# ...         ...                              ...    ...           ...
# 5800  tm1040816      Momshies! Your Soul is Mine  MOVIE          2021
# 5801  tm1014599                        Fine Wine  MOVIE          2021
# 5802  tm1108171                   Edis Starlight  MOVIE          2021
# 5803  tm1045018                            Clash  MOVIE          2021
# 5804  tm1098060                   Shadow Parties  MOVIE          2021
#
#      age_certification  runtime                           genres  \
# ...

# %%
titles5_df = titles4_df[titles4_df['production_countries'].str.contains('US')]
titles5_df
# Out:
#              id                                      title  movie  \
# 1       tm84618                                Taxi Driver  MOVIE
# 4      tm190788                               The Exorcist  MOVIE
# 6       tm14873                                Dirty Harry  MOVIE
# 7      tm185072                               My Fair Lady  MOVIE
# 8       tm98978                            The Blue Lagoon  MOVIE
# ...         ...                                        ...    ...
# 5704  tm1099320           Convergence: Courage in a Crisis  MOVIE
# 5720  tm1019084           Ginny & Georgia - The Afterparty  MOVIE
# 5777  tm1094060                     My Heroes Were Cowboys  MOVIE
# 5780  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5783  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#       release_year age_certification  runtime  \
# 1             1976                 R      113
# 4             1973                 R      133
# ...

# %%
credits_df
# Out:
#        person_id         id                    name      role
# 0           3748    tm84618          Robert De Niro     ACTOR
# 1          14658    tm84618            Jodie Foster     ACTOR
# 2           7064    tm84618           Albert Brooks     ACTOR
# 3           3739    tm84618           Harvey Keitel     ACTOR
# 4          48933    tm84618         Cybill Shepherd     ACTOR
# ...          ...        ...                     ...       ...
# 77208    1347054  tm1098060  Nnenna Rachael Okonkwo     ACTOR
# 77209     157590  tm1098060           Lucien Morgan     ACTOR
# 77210     129059  tm1098060        Magdalena Korpas     ACTOR
# 77211    2050199  tm1098060        Mistura Olusanya     ACTOR
# 77212    2050423  tm1098060              Yemi Amodu  DIRECTOR
#
# [77213 rows x 4 columns]

# %%
cleaned_titles = titles5_df
cleaned_titles
# Out:
#              id                                      title  movie  \
# 1       tm84618                                Taxi Driver  MOVIE
# 4      tm190788                               The Exorcist  MOVIE
# 6       tm14873                                Dirty Harry  MOVIE
# 7      tm185072                               My Fair Lady  MOVIE
# 8       tm98978                            The Blue Lagoon  MOVIE
# ...         ...                                        ...    ...
# 5704  tm1099320           Convergence: Courage in a Crisis  MOVIE
# 5720  tm1019084           Ginny & Georgia - The Afterparty  MOVIE
# 5777  tm1094060                     My Heroes Were Cowboys  MOVIE
# 5780  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5783  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#       release_year age_certification  runtime  \
# 1             1976                 R      113
# 4             1973                 R      133
# ...

# %%
from config import db_password
file_dir = ('./')
import config
from sqlalchemy import create_engine
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Final_Project"

engine = create_engine(db_string)
cleaned_titles.to_sql(name='movie2', con=engine)

# %%
from config import db_password
file_dir = ('./')
import config
from sqlalchemy import create_engine
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/NETFLIX"

engine = create_engine(db_string)
credits_df.to_sql(name='actors', con=engine)
